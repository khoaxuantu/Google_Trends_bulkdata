# %% [markdown]
# ## Import libraries

# %%
import time
import pandas as pd
import pytrends

# %% [markdown]
# ## Connect to Google

# %%
from pytrends.request import TrendReq
pytrends = TrendReq(hl="en-US", tz=0, retries=10)

# %% [markdown]
# ## Get keywords

# %%
keywords = pd.read_excel("keywords.xlsx", usecols="A")
keywords = keywords.sort_values(by=["Key"])
keys = []
for i in keywords.index:
    keys.append(keywords["Key"][i])
print(keys)
# Out:
# ['7Learnings', 'Advanced Pricing Logic', 'Aifora', 'Aimondo', 'Alpha Repricer', 'Aura', 'AvaiBook', 'BEONPRICE', 'BEONx', 'BQool', 'BQool Repricing Central', 'Beyond', 'BlackCurve', 'Boardfy', 'BrightPrice Suite', 'Clear Demand', 'Clear Demand Price Optimization', 'ClearD3', 'Climber Hotel', 'Cloud Store', 'Competera', 'Competitoor', 'DATA SEEKERS', 'DPGO', 'Darwin Pricing', 'Data Bunker', 'Dealavo', 'DemandTec', 'Dynamic Pricing', 'E-Tail Genius', 'EReprice', 'EVA Pricing', 'Eva Commerce', 'FLYR', 'GK AIR', 'GoalProfit', 'Greendeck', 'GrowByData', 'Hypersonix', 'ITELLIGENT', 'Imprice', 'InSiteTrack', 'Intelligence Node', 'LIXAM', 'Listinguish', 'Mercio', 'Minderest', 'Multiply', 'MyForecast', 'Netrivals', 'NextOrbit', 'Omnia', 'Omnia Dynamic Pricing', 'OptiPrice', 'Optimus Price', 'PGP', 'PREXUS', 'PRICEXPERT', 'PROS data science', 'Paarly', 'Pace Revenue', 'Panther Pricing', 'Patagona', 'Premoneo', 'Price Hive', 'Price Trakker', 'Price2Spy', 'PriceComparator', 'PriceEdge', 'PriceGain', 'PriceKit', 'PriceLab', 'PriceManager', 'PriceRest', 'PriceSearch', 'PriceShape', 'PriceStrat', 'PriceTweakers', 'Pricechecker', 'Priceff', 'Pricefx', 'Priceloop', 'Pricemonitor', 'Pricemoov', 'Priceva', 'Pricing HUB', 'Pricing Intelligence', 'Pricing Lifecycle', 'Prisync', 'Q-PERIOR', 'Q_PERIOR Pricing Platform (QPP)', 'Quibble', 'Quicklizard', 'RateGain', 'RateOptics', 'Remi AI', 'RepricerExpress', 'Resteam', 'Revenue AI', 'Revionics', 'RoomPriceGenie', 'SKYSHEEP', 'SYMSON', 'Sardio', 'Sardio Price Monitor', 'Seller Dynamics', 'Seller Republic', 'Seller Snap', 'SellerActive', 'SellerMobile', 'Sellermania', 'Skuuudle', 'Smart Repricing', 'Smartpricing', 'Sniffie', 'Sparkbox', 'Sposea', 'Steinbeis', 'Stratinis', 'Stratinis Pricing Suite Enterprise Edition', 'StreetPricer', 'Syncron', 'Syncron Price', 'Vendrive', 'Verteego', 'Vistaar', 'Vistaar’s Smart Pricing Engine', 'Wheelhouse', 'WisePrice', 'XPLN', 'Yieldigo', 'Zilliant', 'brainbi', 'buynomics', 'dunnhumby', 'idealista', 'itim', 'myPricing', 'netRetail', 'pVelocity', 'priceflo', 'priceintelligence', 'proRMS', 'tgndata', 'xSellco', 'xSellco Repricer']

# %% [markdown]
# ## Build a query loops

# %%
delay = 6
print("Numbers of queries to do: ", len(keywords))

# Prepare containers
errors_list = []
count = 1
trends = {}

# Start loop
for key in keys:
    try:
        time.sleep(delay)
        pytrends.build_payload([key], timeframe="today 12-m", geo="", gprop="")
        trends[key] = pytrends.interest_over_time()[key]
        print(key + f" - Success at loop {count}")
    
    except:
        print(key + f" - Error at loop {count}")
        errors_list.append([key])
    
    count += 1

print(f"\nDone - {len(errors_list)} errors left")
# Out:
# Numbers of queries to do:  146
# 7Learnings - Success at loop 1
# Advanced Pricing Logic - Error at loop 2
# Aifora - Success at loop 3
# Aimondo - Success at loop 4
# Alpha Repricer - Success at loop 5
# Aura - Success at loop 6
# AvaiBook - Success at loop 7
# BEONPRICE - Success at loop 8
# BEONx - Success at loop 9
# BQool - Success at loop 10
# BQool Repricing Central - Error at loop 11
# Beyond - Success at loop 12
# BlackCurve - Success at loop 13
# Boardfy - Success at loop 14
# BrightPrice Suite - Error at loop 15
# Clear Demand - Success at loop 16
# Clear Demand Price Optimization - Error at loop 17
# ClearD3 - Error at loop 18
# Climber Hotel - Success at loop 19
# Cloud Store - Success at loop 20
# Competera - Success at loop 21
# Competitoor - Success at loop 22
# DATA SEEKERS - Success at loop 23
# DPGO - Success at loop 24
# Darwin Pricing - Success at loop 25
# Data Bunker - Success at loop 26
# Dealavo - Success at loop 27
# DemandTec - Success at loop 28
# Dynamic Pricing - Success at loop 29
# E-Tail Genius - Error at loop 30
# EReprice - Success at loop 31
# EVA Pricing - Success at loop 32
# Eva Commerce - Success at loop 33
# FLYR - Success at loop 34
# GK AIR - Success at loop 35
# GoalProfit - Success at loop 36
# Greendeck - Success at loop 37
# GrowByData - Success at loop 38
# Hypersonix - Success at loop 39
# ITELLIGENT - Success at loop 40
# Imprice - Success at loop 41
# InSiteTrack - Error at loop 42
# Intelligence Node - Success at loop 43
# LIXAM - Success at loop 44
# Listinguish - Error at loop 45
# Mercio - Success at loop 46
# Minderest - Success at loop 47
# Multiply - Success at loop 48
# MyForecast - Success at loop 49
# Netrivals - Success at loop 50
# NextOrbit - Success at loop 51
# Omnia - Success at loop 52
# Omnia Dynamic Pricing - Error at loop 53
# OptiPrice - Error at loop 54
# Optimus Price - Success at loop 55
# PGP - Success at loop 56
# PREXUS - Success at loop 57
# PRICEXPERT - Error at loop 58
# PROS data science - Success at loop 59
# Paarly - Success at loop 60
# Pace Revenue - Success at loop 61
# Panther Pricing - Success at loop 62
# Patagona - Success at loop 63
# Premoneo - Success at loop 64
# Price Hive - Success at loop 65
# Price Trakker - Success at loop 66
# Price2Spy - Success at loop 67
# PriceComparator - Error at loop 68
# PriceEdge - Error at loop 69
# PriceGain - Success at loop 70
# PriceKit - Success at loop 71
# PriceLab - Success at loop 72
# PriceManager - Error at loop 73
# PriceRest - Error at loop 74
# PriceSearch - Success at loop 75
# PriceShape - Success at loop 76
# PriceStrat - Error at loop 77
# PriceTweakers - Success at loop 78
# Pricechecker - Success at loop 79
# Priceff - Success at loop 80
# Pricefx - Success at loop 81
# Priceloop - Success at loop 82
# Pricemonitor - Success at loop 83
# Pricemoov - Success at loop 84
# Priceva - Success at loop 85
# Pricing HUB - Success at loop 86
# Pricing Intelligence - Success at loop 87
# Pricing Lifecycle - Success at loop 88
# Prisync - Success at loop 89
# Q-PERIOR - Success at loop 90
# Q_PERIOR Pricing Platform (QPP) - Error at loop 91
# Quibble - Success at loop 92
# Quicklizard - Success at loop 93
# RateGain - Success at loop 94
# RateOptics - Error at loop 95
# Remi AI - Success at loop 96
# RepricerExpress - Success at loop 97
# Resteam - Success at loop 98
# Revenue AI - Success at loop 99
# Revionics - Success at loop 100
# RoomPriceGenie - Success at loop 101
# SKYSHEEP - Success at loop 102
# SYMSON - Success at loop 103
# Sardio - Success at loop 104
# Sardio Price Monitor - Error at loop 105
# Seller Dynamics - Success at loop 106
# Seller Republic - Success at loop 107
# Seller Snap - Success at loop 108
# SellerActive - Success at loop 109
# SellerMobile - Success at loop 110
# Sellermania - Success at loop 111
# Skuuudle - Success at loop 112
# Smart Repricing - Error at loop 113
# Smartpricing - Success at loop 114
# Sniffie - Success at loop 115
# Sparkbox - Success at loop 116
# Sposea - Success at loop 117
# Steinbeis - Success at loop 118
# Stratinis - Success at loop 119
# Stratinis Pricing Suite Enterprise Edition - Error at loop 120
# StreetPricer - Success at loop 121
# Syncron - Success at loop 122
# Syncron Price - Error at loop 123
# Vendrive - Success at loop 124
# Verteego - Success at loop 125
# Vistaar - Success at loop 126
# Vistaar’s Smart Pricing Engine - Error at loop 127
# Wheelhouse - Success at loop 128
# WisePrice - Success at loop 129
# XPLN - Success at loop 130
# Yieldigo - Success at loop 131
# Zilliant - Success at loop 132
# brainbi - Success at loop 133
# buynomics - Success at loop 134
# dunnhumby - Success at loop 135
# idealista - Success at loop 136
# itim - Success at loop 137
# myPricing - Error at loop 138
# netRetail - Success at loop 139
# pVelocity - Success at loop 140
# priceflo - Success at loop 141
# priceintelligence - Error at loop 142
# proRMS - Error at loop 143
# tgndata - Error at loop 144
# xSellco - Success at loop 145
# xSellco Repricer - Error at loop 146
#
# Done - 28 errors left

# %%
print(errors_list)
for key in errors_list:
    print(key[0])
# Out:
# [['Advanced Pricing Logic'], ['BQool Repricing Central'], ['BrightPrice Suite'], ['Clear Demand Price Optimization'], ['ClearD3'], ['E-Tail Genius'], ['InSiteTrack'], ['Listinguish'], ['Omnia Dynamic Pricing'], ['OptiPrice'], ['PRICEXPERT'], ['PriceComparator'], ['PriceEdge'], ['PriceManager'], ['PriceRest'], ['PriceStrat'], ['Q_PERIOR Pricing Platform (QPP)'], ['RateOptics'], ['Sardio Price Monitor'], ['Smart Repricing'], ['Stratinis Pricing Suite Enterprise Edition'], ['Syncron Price'], ['Vistaar’s Smart Pricing Engine'], ['myPricing'], ['priceintelligence'], ['proRMS'], ['tgndata'], ['xSellco Repricer']]
# Advanced Pricing Logic
# BQool Repricing Central
# BrightPrice Suite
# Clear Demand Price Optimization
# ClearD3
# E-Tail Genius
# InSiteTrack
# Listinguish
# Omnia Dynamic Pricing
# OptiPrice
# PRICEXPERT
# PriceComparator
# PriceEdge
# PriceManager
# PriceRest
# PriceStrat
# Q_PERIOR Pricing Platform (QPP)
# RateOptics
# Sardio Price Monitor
# Smart Repricing
# Stratinis Pricing Suite Enterprise Edition
# Syncron Price
# Vistaar’s Smart Pricing Engine
# myPricing
# priceintelligence
# proRMS
# tgndata
# xSellco Repricer

# %% [markdown]
# ## Tackle errors
# Redo searches with errors

# %%
loop = 2

if len(errors_list) > 0:
    print("\nStart errors:")

    for t in range(loop):
        if len(errors_list) > 0:
            print(f"Loop {t}: {len(errors_list)} errors left")

            for keyword in errors_list:
                try:
                    time.sleep(delay)
                    pytrends.build_payload([keyword[0]], timeframe="today 12-m", geo="", gprop="")
                    trends[keyword[0]] = pytrends.interest_over_time()[keyword[0]]
                    print(f"{keyword[0]} - Success")
                except:
                    print(f"{keyword[0]} - Error")
                    if (t == loop-1):
                        trends[keyword[0]] = pd.DataFrame()
                    pass
        else:
            break

print(f"\n Done - {len(errors_list)} errors left")
# Out:
# Start errors:
# Loop 0: 28 errors left
# Advanced Pricing Logic - Error
# BQool Repricing Central - Error
# BrightPrice Suite - Error
# Clear Demand Price Optimization - Error
# ClearD3 - Error
# E-Tail Genius - Error
# InSiteTrack - Error
# Listinguish - Error
# Omnia Dynamic Pricing - Error
# OptiPrice - Error
# PRICEXPERT - Error
# PriceComparator - Error
# PriceEdge - Error
# PriceManager - Error
# PriceRest - Error
# PriceStrat - Error
# Q_PERIOR Pricing Platform (QPP) - Error
# RateOptics - Error
# Sardio Price Monitor - Error
# Smart Repricing - Error
# Stratinis Pricing Suite Enterprise Edition - Error
# Syncron Price - Error
# Vistaar’s Smart Pricing Engine - Error
# myPricing - Error
# priceintelligence - Error
# proRMS - Error
# tgndata - Error
# xSellco Repricer - Error
# Loop 1: 28 errors left
# Advanced Pricing Logic - Error
# BQool Repricing Central - Error
# BrightPrice Suite - Error
# Clear Demand Price Optimization - Error
# ClearD3 - Error
# E-Tail Genius - Error
# InSiteTrack - Error
# Listinguish - Error
# Omnia Dynamic Pricing - Error
# OptiPrice - Error
# PRICEXPERT - Error
# PriceComparator - Error
# PriceEdge - Error
# PriceManager - Error
# PriceRest - Error
# PriceStrat - Error
# Q_PERIOR Pricing Platform (QPP) - Error
# RateOptics - Error
# Sardio Price Monitor - Error
# Smart Repricing - Error
# Stratinis Pricing Suite Enterprise Edition - Error
# Syncron Price - Error
# Vistaar’s Smart Pricing Engine - Error
# myPricing - Error
# priceintelligence - Error
# proRMS - Error
# tgndata - Error
# xSellco Repricer - Error
#
#  Done - 28 errors left

# %% [markdown]
# ## Save to CSV file

# %%
dict_of_trends = {"global": pd.DataFrame(trends)}
data_df = pd.concat(dict_of_trends, axis=1)
data_df.to_csv("output.csv", index=False)
data_df.head()
# Out:
#                global
#            7Learnings Aifora Aimondo Alpha Repricer Aura AvaiBook BEONPRICE
# date
# 2022-04-24          0      0      25              0   91       49         0  \
# 2022-05-01          0      0      14              0   86       48         0
# 2022-05-08          0      0      24              0   82       48         0
# 2022-05-15          0      0      27              0   82       39        68
# 2022-05-22          0      0       0             53   78       80         0
#
#                                ...
#            BEONx BQool Beyond  ... Zilliant brainbi buynomics dunnhumby
# date                           ...
# 2022-04-24    86    54     69  ...       18       0         0        78  \
# 2022-05-01    65    40     67  ...       16       0         0        78
# 2022-05-08    30    23     66  ...       30       0         0        70
# 2022-05-15    54    42     64  ...        0       0         0        51
# 2022-05-22    12    19     68  ...       45      31         0        57
#
#
#            idealista itim netRetail pVelocity priceflo xSellco
# date
# 2022-04-24        93   27        36        22        0       0
# 2022-05-01        92   24         0         0        0      60
# 2022-05-08        90   24         0         0       59      43
# 2022-05-15        89   27        52         0        0      57
# 2022-05-22        90   24       100         0        0      80
#
# [5 rows x 118 columns]
